# %%
from data_utils import *

SeasonList = [2005, 2006,2007,2008,2009,2010,2011, 2012,2013]

#X_TRAIN, Y_TRAIN = createTrainingData(SeasonList)
#X_DATA, Y_DATA = createTrainingData(SeasonList)
X_DATA, Y_DATA = createData(SeasonList, "data/")


X_DATA


Y_DATA


print("XDATA length" ,len(X_DATA))

X_DATA[1]

type(X_DATA)

splitindex = (int)(0.7*len(X_DATA))
X_TRAIN = X_DATA[:splitindex]
X_TEST= X_DATA[splitindex:]
Y_TRAIN = Y_DATA[:splitindex]
Y_TEST= Y_DATA[splitindex:]

print (len(X_TRAIN))
print (len(X_TEST))
print (len(Y_TRAIN))
print (len(Y_TEST))

X_TRAIN[:, :2]

X_TRAIN[1]
# Out:
# GameList size:  718
# TeamList size:  166
# X_train size:  618
# Y_train size:  618
# GameList size:  792
# TeamList size:  179
# X_train size:  692
# Y_train size:  692
# GameList size:  792
# TeamList size:  183
# X_train size:  692
# Y_train size:  692
# GameList size:  804
# TeamList size:  189
# X_train size:  704
# Y_train size:  704
# GameList size:  808
# TeamList size:  195
# X_train size:  708
# Y_train size:  708
# GameList size:  808
# TeamList size:  195
# X_train size:  708
# Y_train size:  708
# GameList size:  812
# TeamList size:  197
# X_train size:  712
# Y_train size:  712
# GameList size:  838
# TeamList size:  203
# X_train size:  738
# Y_train size:  738
# GameList size:  848
# TeamList size:  207
# X_train size:  748
# Y_train size:  748
# XDATA length 6320
# 4424
# 1896
# 4424
# 1896
# array(['0.0', '0.0', '-35.0', '0.0', '1342.0', '2138.0', '14.0', '16.0',
#        '362.0', '237.0', '11.5', '2.0', '1.0', '1.0434782608695652',
# ...

# %%
X_TRAIN.shape
# Out:
# (4424, 17)

# %%
import torch
import torch.nn as nn

import argparse

import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import torch
import torch.nn as nn
import torch.optim as optim
import torchnet as tnt
from sklearn.datasets.samples_generator import make_blobs
from torch.autograd import Variable

X = X_TRAIN
y= Y_TRAIN

########### PLOTTING WIN RATIO AND POINT DIFFERENCE OF BOTH TEAMS VS OUTCOME OF THE MATCH (0 OR 1)
def visualize_WinRatio_data():
    X = X_TRAIN[:, :2]
    y = Y_TRAIN[:,0]
    plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.coolwarm)
    plt.xlabel('HTeam Win Ratio')
    plt.ylabel('VTeam Win Ratio')
    plt.title('Win Ratio HTeam & VTeam')
    plt.colorbar()
    plt.show()

visualize_WinRatio_data()


def visualize_pointdiff_data():
    X = X_TRAIN   #[:, 2:]
    y = Y_TRAIN[:,0]
    plt.scatter(X[:, 2], X[:, 3], c=y, cmap=plt.cm.coolwarm)
    plt.xlabel('HTeam Point Difference')
    plt.ylabel('VTeam Point Difference')
    plt.title('Point Difference HTeam & VTeam')
    plt.colorbar()
    plt.show()

visualize_pointdiff_data()





########### PLOTTING WINRATIO AND POINT DIFFERENCE OF BOTH TEAMS VS Y - POINT DIFFERENCE IN THE SCORE OF MATCH
def visualize_WinRatio_data():
    X = X_TRAIN[:, :2]
    y = Y_TRAIN[:,1]
    plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.coolwarm)
    plt.xlabel('HTeam Win Ratio')
    plt.ylabel('VTeam Win Ratio')
    plt.title('Win Ratio HTeam & VTeam')
    plt.colorbar()
    plt.show()

visualize_WinRatio_data()


def visualize_pointdiff_data():
    X = X_TRAIN   #[:, 2:]
    y = Y_TRAIN[:,1]
    plt.scatter(X[:, 2], X[:, 3], c=y, cmap=plt.cm.coolwarm)
    plt.xlabel('HTeam Point Difference')
    plt.ylabel('VTeam Point Difference')
    plt.title('Point Difference HTeam & VTeam')
    plt.colorbar()
    plt.show()

visualize_pointdiff_data()
